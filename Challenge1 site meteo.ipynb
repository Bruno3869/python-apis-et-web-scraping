# %% [markdown]
# # Challenge 1 Site Météo

# %% [markdown]
# ## Exploration de la structure de la page Web

# %% [markdown]
# ### Training

# %%
import requests
# Librairie BeautifulSoup du package bs4
from bs4 import BeautifulSoup

# %%
#Solution Bruno
# Télécharger la page
response = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996")
content = response.content
parser = BeautifulSoup(content, 'html.parser')

# Assigner l'id seven-day-forecast à la variable seven_day
seven_day = parser.select("#seven-day-forecast")[0].select(".short-desc")[0].text
print(seven_day)
# Out:
# Sunny

# %%
#Solution Rod
# Télécharger la page
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
today = forecast_items[0]
print(today.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   This
#   <br/>
#   Afternoon
#  </p>
#  <p>
#   <img alt="This Afternoon: Sunny, with a high near 70. West wind 11 to 18 mph, with gusts as high as 24 mph. " class="forecast-icon" src="newimages/medium/skc.png" title="This Afternoon: Sunny, with a high near 70. West wind 11 to 18 mph, with gusts as high as 24 mph. "/>
#  </p>
#  <p class="short-desc">
#   Sunny
#  </p>
#  <p class="temp temp-high">
#   High: 70 °F
#  </p>
# </div>
