# %% [markdown]
# # Challenge 1 Site Météo

# %% [markdown]
# ## Exploration de la structure de la page Web

# %% [markdown]
# ### Training

# %%
# conda install -c anaconda beautifulsoup4 à faire avant dans la console
import requests
# Librairie BeautifulSoup du package bs4
from bs4 import BeautifulSoup

# %%
#Solution Bruno
# Télécharger la page
response = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996")
content = response.content
parser = BeautifulSoup(content, 'html.parser')

# Assigner l'id seven-day-forecast à la variable seven_day
seven_day = parser.select("#seven-day-forecast")[0].select(".short-desc")[0].text
print(seven_day)
# Out:
# Chance Rain

# %%
#Solution Rod
# Télécharger la page
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
today = forecast_items[0]
print(today.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   This
#   <br/>
#   Afternoon
#  </p>
#  <p>
#   <img alt="This Afternoon: A 30 percent chance of rain after 2pm.  Partly sunny, with a steady temperature around 61. Southwest wind 16 to 18 mph, with gusts as high as 24 mph.  New precipitation amounts of less than a tenth of an inch possible. " class="forecast-icon" src="newimages/medium/ra30.png" title="This Afternoon: A 30 percent chance of rain after 2pm.  Partly sunny, with a steady temperature around 61. Southwest wind 16 to 18 mph, with gusts as high as 24 mph.  New precipitation amounts of less than a tenth of an inch possible. "/>
#  </p>
#  <p class="short-desc">
#   Chance Rain
#  </p>
#  <p class="temp temp-high">
#   High: 61 °F
#  </p>
# </div>

# %% [markdown]
# ## Extraire toutes les informations d'un élément

# %% [markdown]
# ### Training

# %%
# Extraire le nom de l'objet forecast, la courte description et la température
forecast = today.find(class_="period-name").get_text()
short_desc = today.find(class_="short-desc").get_text()
temperature = today.find(class_="temp").get_text()
print(forecast)
print(short_desc)
print(temperature)
# Out:
# ThisAfternoon
# Chance Rain
# High: 61 °F

# %%
img = today.find("img")
desc = img["title"] # img est un dictionnaire, on récupère title avec un []
print(desc)
# Out:
# This Afternoon: A 30 percent chance of rain after 2pm.  Partly sunny, with a steady temperature around 61. Southwest wind 16 to 18 mph, with gusts as high as 24 mph.  New precipitation amounts of less than a tenth of an inch possible.
